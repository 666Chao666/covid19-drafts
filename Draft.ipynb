# %%
import os
import numpy as np
import pandas as pd

# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials
import pandas as pd

scope = ['https://spreadsheets.google.com/feeds',
         'https://www.googleapis.com/auth/drive']

credentials = ServiceAccountCredentials.from_json_keyfile_name(
         'covid19-protestdata-07d0d4a06185.json', scope) # Your json file here

gc = gspread.authorize(credentials)

# %%
wks = gc.open("NYC subway data").sheet1

data = wks.get_all_values()
headers = data.pop(0)

df = pd.DataFrame(data, columns=headers)
print(df.head())

# %%
gc.open("Crowd Estimates May 2020")
# Out:
# ---------------------------------------------------------------------------
# APIError                                  Traceback (most recent call last)
# <ipython-input-2-7e70ef6e3065> in <module>
# ----> 1 gc.open("Crowd Estimates May 2020")
#
# D:\cs\189\venv\lib\site-packages\gspread\client.py in open(self, title)
#     117             properties = finditem(
#     118                 lambda x: x['name'] == title,
# --> 119                 self.list_spreadsheet_files(title),
#     120             )
#     121
#
# D:\cs\189\venv\lib\site-packages\gspread\client.py in list_spreadsheet_files(self, title)
#      93                 params['pageToken'] = page_token
#      94
# ---> 95             res = self.request('get', url, params=params).json()
#      96             files.extend(res['files'])
#      97             page_token = res.get('nextPageToken', None)
#
# D:\cs\189\venv\lib\site-packages\gspread\client.py in request(self, method, endpoint, params, data, json, files, headers)
# ...

# %%
from __future__ import print_function
from apiclient.discovery import build
from httplib2 import Http
from oauth2client import file, client, tools

# %%
SPREADSHEET_ID = '1pZo5p9EKZJ87IvPVjIp50nQQPET_ucV8vKVfZ6NpOvg'
RANGE_NAME = 'Tally'

# %%
def get_google_sheet(spreadsheet_id, range_name):
    """ Retrieve sheet data using OAuth credentials and Google Python API. """
    scopes = 'https://www.googleapis.com/auth/spreadsheets.readonly'
    # Setup the Sheets API
    store = file.Storage('credentials.json')
    creds = store.get()
    if not creds or creds.invalid:
        flow = client.flow_from_clientsecrets('client_secret.json', scopes)
        creds = tools.run_flow(flow, store)
    service = build('sheets', 'v4', http=creds.authorize(Http()))

    # Call the Sheets API
    gsheet = service.spreadsheets().values().get(spreadsheetId=spreadsheet_id, range=range_name).execute()
    return gsheet


def gsheet2df(gsheet):
    """ Converts Google sheet data to a Pandas DataFrame.
    Note: This script assumes that your data contains a header file on the first row!
    Also note that the Google API returns 'none' from empty cells - in order for the code
    below to work, you'll need to make sure your sheet doesn't contain empty cells,
    or update the code to account for such instances.
    """
    header = gsheet.get('values', [])[0]   # Assumes first line is header!
    values = gsheet.get('values', [])[1:]  # Everything else is data.
    if not values:
        print('No data found.')
    else:
        all_data = []
        for col_id, col_name in enumerate(header):
            column_data = []
            for row in values:
                column_data.append(row[col_id])
            ds = pd.Series(data=column_data, name=col_name)
            all_data.append(ds)
        df = pd.concat(all_data, axis=1)
    return df

# %%
gsheet = get_google_sheet(SPREADSHEET_ID, RANGE_NAME)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-baf7280246ec> in <module>
# ----> 1 gsheet = get_google_sheet(SPREADSHEET_ID, RANGE_NAME)
#
# <ipython-input-4-6f8725498e51> in get_google_sheet(spreadsheet_id, range_name)
#       4     # Setup the Sheets API
#       5     store = file.Storage('credentials.json')
# ----> 6     creds = store.get()
#       7     if not creds or creds.invalid:
#       8         flow = client.flow_from_clientsecrets('client_secret.json', scopes)
#
# D:\cs\189\venv\lib\site-packages\oauth2client\client.py in get(self)
#     405         self.acquire_lock()
#     406         try:
# --> 407             return self.locked_get()
#     408         finally:
#     409             self.release_lock()
#
# D:\cs\189\venv\lib\site-packages\oauth2client\file.py in locked_get(self)
#      52
#      53         try:
# ...

# %%
df = gsheet2df(gsheet)
print('Dataframe size = ', df.shape)
print(df.head())

# %%
1pZo5p9EKZJ87IvPVjIp50nQQPET_ucV8vKVfZ6NpOvg/edit#gid=1538635238

# %%
tally_url = 'https://docs.google.com/spreadsheets/d/1pZo5p9EKZJ87IvPVjIp50nQQPET_ucV8vKVfZ6NpOvg/export?format=csv&gid=0'
gf_url = 'https://docs.google.com/spreadsheets/d/1pZo5p9EKZJ87IvPVjIp50nQQPET_ucV8vKVfZ6NpOvg/export?format=csv&gid=1571725208'

# %%
tally_df = pd.read_csv(new_google_sheet_url)
gf_df = pd.read_csv(gf_url)

# %%
gf_df.tail(10)
# Out:
#                                                      F              Location  \
# 785  NOTE: DO NOT ENTER JUNE DATES HERE; tally cont...                   NaN
# 786                                        Albuqeurque  route 66 to downtown
# 787                                                NaN                   NaN
# 788  tally continues on June spreadsheet: https://d...                   NaN
# 789                                                NaN                   NaN
# 790                                                NaN                   NaN
# 791                                                NaN                   NaN
# 792                                                NaN                   NaN
# 793                                                NaN                   NaN
# 794                                                NaN                   NaN
#
#     County StateTerritory Country        Date EstimateText  EstimateLow  \
# ...

# %%
gf_df[~(gf_df['County'].isna() | gf_df['StateTerritory'].isna())]
# Out:
#                F                                           Location  \
# 0          Tulsa                                      Interstate 44
# 1        Hammond                          Hammond Police Department
# 2        Houston                                    Discovery Green
# 3    Los Angeles                                           Downtown
# 4    Minneapolis  site of Floyd's arrest; Minneapolis Police Dep...
# ..           ...                                                ...
# 780  Wilmington                                            Downtown
# 781     Winfield                                                NaN
# 782      Wooster                     northeast corner of the square
# 783      Yonkers                                  Yonkers City Hall
# 784   Youngstown             toward the Mahoning County Court House
#
#           County StateTerritory Country        Date  \
# 0          Tulsa             OK      US  2020-05-25
# ...

# %%
tally_df[~(tally_df['County'].isna() | tally_df['StateTerritory'].isna())]
# Out:
#             CityTown                                           Location  \
# 0             Albany                                      State Capitol
# 1           Alhambra                   Alhambra Hospital Medical Center
# 2            Anaheim                 Anaheim Global Medical Center, Inc
# 3            Anaheim                        West Anaheim Medical Center
# 4          Ann Arbor                         Whole Foods to USPS office
# ..               ...                                                ...
# 680       New London                                                NaN
# 681  Prescott Valley                  Prescott Valley Police Department
# 682      Santa Maria                                                NaN
# 683      San Antonio                      San Antonio Housing Authority
# 684      Hattiesburg  entrance to the University of Southern Mississ...
#
#             County StateTerritory Country        Date   EstimateText  \
# ...

# %%
type(tally_df["Date"][0])
# Out:
# str
